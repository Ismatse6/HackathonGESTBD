# %%
import requests

GRAPHDB_ENDPOINT = "http://localhost:8000/repositories/asignaturas"

# %% [markdown]
# # Consulta 1
# Todas las asignaturas impartidas por una escuela

# %%
query = """
PREFIX upm: <http://upm.es/ontology/>
SELECT ?nombre_escuela ?nombre_asignatura
WHERE {
    # ?s a upm:Escuela .
    # ?s upm:nombre ?nombre_escuela .
    # ?s upm:imparteTitulacion ?t .
    # ?t upm:incluyeAsignatura ?a .
    # ?a upm:nombre ?nombre_asignatura .
} LIMIT 100
"""

response = requests.post(
    GRAPHDB_ENDPOINT,
    data={'query': query},
    headers={'Accept': 'application/sparql-results+json'}
)

if response.status_code == 200:
    results = response.json()
    for r in results['results']['bindings']:
        print(r)
else:
    print("Error:", response.status_code, response.text)
# Out:
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Métodos Clásicos para Predicción'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Cálculo I'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Cálculo II'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Bases de Datos II'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Probabilidades y Estadística I'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Adquisición y Procesamiento Numérico de Datos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Descubrimiento de Conocimiento en Datos Complejos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Representación e Intercambio de Datos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Programación para Ciencia de Datos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Visualización de Información'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Arquitecturas para el Procesamiento Masivo de Datos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Infraestructuras de Big Data'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Inteligencia Artificial'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Métodos Generativos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Aspectos Sociales, éticos y Legales de los Datos y la\nInteligencia Artificial'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Web Semántica, Linked Data y Grafos de Conocimientos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Internet de las Cosas (Iot)'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Infraestructuras y Servicios Cloud'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Algorítmica Numérica'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Seguridad de las Tecnologías de la Información'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de la Programación'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Procesamiento de Lenguaje Natural'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de Economía y Administración de Empresas'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Matemática Discreta I'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Bases de Datos I'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Aprendizaje Automático I'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'álgebra Lineal'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Computación Social y Personalización'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Matemática Discreta II'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Proyecto de Ciencia de Datos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de Análisis de Imágenes'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Robótica'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Algoritmos y Estructuras de Datos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Aprendizaje Automático II'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Investigación Operativa'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de los Computadores'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Lógica para Inteligencia Artificial'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Probabilidades y Estadística II'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Logica y Matematica Discreta'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Desarrollo de Sistemas de Informacion Orientados a\nServicios'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Auditoria y Control Ti'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de Economia y Empresa'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Algebra'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Inteligencia Artificial'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Traductores de Lenguajes de Programacion'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Aspectos Eticos y Sociales'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Bases de Datos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Sistemas de Informacion Geografica'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Aspectos Legales y Profesionales'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Seguridad de la Informacion'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Taller de Sistemas Operativos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Sistemas de Soporte a la Toma de Decisiones'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de Computadores'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Bases de Datos Avanzadas'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Analisis Matematico'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Estructura de Datos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Probabilidad y Estadística'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Metricas y Modelos para el Control y Gestion de Servicios'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Redes de Computadores'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos Fisicos de la Informatica'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de Ingenieria de Software'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Mineria de Datos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Gestion de Proyectos de Sistemas de Informacion'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de Sistemas de Informacion'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Arquitectura de Computadores'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Programacion Concurrente y Avanzada'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Mejores Practicas para Gestion de Servicios'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Analisis y Desarrollo Estrategico de Empresas'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Programacion Orientada a Objetos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de Seguridad'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Sistemas Operativos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de Programacion'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Estructura de Computadores'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Algoritmica y Complejidad'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Planificacion y Organización del Capital Humano'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Taller de Programacion'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de Programacion'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Sistemas de Tiempo Real'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Robotica'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Programacion de Hw Reconfigurable'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Estructura de Datos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Logica y Matematica Discreta'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Taller de Programacion'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Inteligencia Artificial'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Taller de Sistemas Operativos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Probabilidad y Estadistica'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Arquitectura de Computadores'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Bases de Datos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Programacion Concurrente y Avanzada'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Aspectos Legales y Profesionales'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Sistemas Operativos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Arquitecturas Avanzadas'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Programacion Orientada a Objetos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Sistemas y Servicios de Navegación Gps'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Seguridad de la Informacion'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Aspectos Eticos y Sociales'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Seguridad en Sistemas y Redes'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Analisis Matematico'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de Economia y Empresa'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_asignatura': {'type': 'literal', 'value': 'Fundamentos de Seguridad'}}

# %% [markdown]
# # Consulta 2
# Encontrar la escuela a la que pertenece el profesor de una asignatura

# %%
query = """
PREFIX upm: <http://upm.es/ontology/>
SELECT ?nombre_escuela ?nombre_profesor
WHERE {
    # ?e a upm:Escuela .
    # ?e upm:nombre ?nombre_escuela .
    # ?e upm:imparteTitulacion ?t .
    # ?t upm:incluyeAsignatura ?a .
    # ?a upm:tieneProfesor ?p .
    # ?p upm:nombre ?nombre_profesor .
} LIMIT 100
"""

response = requests.post(
    GRAPHDB_ENDPOINT,
    data={'query': query},
    headers={'Accept': 'application/sparql-results+json'}
)

if response.status_code == 200:
    results = response.json()
    for r in results['results']['bindings']:
        print(r)
else:
    print("Error:", response.status_code, response.text)
# Out:
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Alejandro Martin Garcia'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Rafael Miñano Rubio'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Luis Miguel Pozo Coronado'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jose Merodio Gomez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Rodrigo Javier Raya'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Angel Panizo Lledot'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Aranzazu Corral Herrero'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Esther Dopazo Gonzalez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Rodrigo Mariño Andres'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Antonio Tabernero Galan'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Joaquin Gayoso Cabada'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Carlos Badenes Olmedo'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Borja Bordel Sanchez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Abraham Gutierrez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jesus Bobadilla Sancho'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Manuel Ottaviano'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Carlos Castilla Ruiz'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Bonifacio Alberto Mozo'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Carlos Badenes Olmedo'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jose Eugenio Naranjo'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Francisco Serradilla Garcia'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Guillermo Iglesias'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Edgar Talavera Muñoz'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jorge Dueñas Lerin'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Aurea Maria Anguera De'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Maria Celia Fernandez Aller'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Andrea Jesus Cimmino'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Vicente Angel Garcia'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Fco. Javier Gil Rubio'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Juan Manuel Castelo Gomez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Enrique Gutierrez Alvarez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Giannicola Scarpa'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Abraham Gutierrez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jesus Bobadilla Sancho'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Alejandro Martin Garcia'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Marta Olea De Cardenas'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jaime Juan Gonzalez Masip'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Manuel Uche Soria'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'M. Paula Fernandez Arias'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jesus Garcia Lopez De'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Alberto Diaz Alvarez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Fernando Ortega Requena'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'David Camacho Fernandez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Ana Isabel Lias Quintero'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Cristian Oliver Ramirez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Raul Lara Cabrera'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jesus Garcia Lopez De'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Abraham Gutierrez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jesus Bobadilla Sancho'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Angel Arroyo Castillo'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jose Eugenio Naranjo'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Alfredo Valle Barrio'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Juan Alberto De Frutos'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Miguel Angel Diaz Martinez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Raul Lara Cabrera'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Francisco Serradilla Garcia'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Carlos Quesada Gonzalez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'M. Elvira Martinez De Icaya'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Roberto Muñoz Izquierdo'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Celena Lorenzo Navarro'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jesus Garcia Lopez De'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Roberto Muñoz Izquierdo'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Agustin Yague Panadero'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jose Luis Sanchez Sanchez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Juan Manuel Castelo Gomez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Juan Garbajosa Sopeña'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Marta Olea De Cardenas'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jaime Juan Gonzalez Masip'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Manuel Uche Soria'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'M. Paula Fernandez Arias'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Ana Isabel Lias Quintero'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Gregoria Blanco Viejo'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Ana Belen Cristobal Lopez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Carlos Peon Nieto'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Javier Huertas Tato'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Angel Arroyo Castillo'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Cristian Oliver Ramirez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jose Ramon Sanchez Couso'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Joaquin Gayoso Cabada'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Victor Rodriguez Fernandez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Victor Mitrana'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': "Sergio Alejandro D'antonio"}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Aurea Maria Anguera De'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Maria Celia Fernandez Aller'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Maria Angeles Mahillo'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Santiago Alonso Villaverde'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Maria Gema Bello Orgaz'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Edgar Talavera Muñoz'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Fernando Ortega Requena'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Raul Lara Cabrera'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Helena Liz Lopez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Maria Celia Fernandez Aller'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jorge Blasco Alis'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Juan Manuel Castelo Gomez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Jose Ernesto Jimenez'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Pilar Manzano Garcia'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Andres Sevilla De Pablo'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Pedro Pablo Alarcon Cavero'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Giannicola Scarpa'}}
# {'nombre_escuela': {'type': 'literal', 'value': 'E.T.S De Ing. De Sistemas Informáticos'}, 'nombre_profesor': {'type': 'literal', 'value': 'Maria Navas Loro'}}

# %% [markdown]
# # Consulta 3
# Profesores que imparten más de N asignaturas

# %%
query = """
PREFIX upm: <http://upm.es/ontology/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT ?profesor ?nombre (COUNT(?asig) AS ?numAsignaturas) WHERE {
  # ?asig rdf:type upm:Asignatura .
  # ?asig upm:tieneProfesor ?profesor .
  OPTIONAL { ?profesor upm:nombre ?nombre. }
}
GROUP BY ?profesor ?nombre
HAVING (COUNT(?asig) > 4)
ORDER BY DESC(?numAsignaturas)
"""

response = requests.post(
    GRAPHDB_ENDPOINT,
    data={'query': query},
    headers={'Accept': 'application/sparql-results+json'}
)

if response.status_code == 200:
    results = response.json()
    for r in results['results']['bindings']:
        print(r)
else:
    print("Error:", response.status_code, response.text)
# Out:
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/5'}, 'nombre': {'type': 'literal', 'value': 'Joaquin Gayoso Cabada'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '13'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/54'}, 'nombre': {'type': 'literal', 'value': 'Cristian Oliver Ramirez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '10'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/66'}, 'nombre': {'type': 'literal', 'value': 'Maria Angeles Mahillo'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '9'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/14'}, 'nombre': {'type': 'literal', 'value': 'Rafael Miñano Rubio'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '9'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/6'}, 'nombre': {'type': 'literal', 'value': 'Carlos Castilla Ruiz'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '9'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/92'}, 'nombre': {'type': 'literal', 'value': 'Maria Celia Fernandez Aller'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '9'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/11'}, 'nombre': {'type': 'literal', 'value': 'Gregoria Blanco Viejo'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '8'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/53'}, 'nombre': {'type': 'literal', 'value': 'Javier Huertas Tato'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '8'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/27'}, 'nombre': {'type': 'literal', 'value': 'Andres Sevilla De Pablo'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '8'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/72'}, 'nombre': {'type': 'literal', 'value': 'Agustin Yague Panadero'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '8'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/42'}, 'nombre': {'type': 'literal', 'value': 'Francisco Aylagas Romero'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '8'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/82'}, 'nombre': {'type': 'literal', 'value': 'Carlos Camacho Gomez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '8'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/26'}, 'nombre': {'type': 'literal', 'value': 'Jordi Burguet Castell'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '8'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/44'}, 'nombre': {'type': 'literal', 'value': 'Rodrigo Javier Raya'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '7'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/39'}, 'nombre': {'type': 'literal', 'value': 'Juan Manuel Castelo Gomez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '7'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/28'}, 'nombre': {'type': 'literal', 'value': 'Pilar Manzano Garcia'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '7'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/77'}, 'nombre': {'type': 'literal', 'value': 'Jorge Dueñas Lerin'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '7'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/41'}, 'nombre': {'type': 'literal', 'value': 'Jose Gutierrez Fernandez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '7'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/22'}, 'nombre': {'type': 'literal', 'value': 'Carlos Badenes Olmedo'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/55'}, 'nombre': {'type': 'literal', 'value': 'Antonio Hernando Esteban'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/98'}, 'nombre': {'type': 'literal', 'value': 'Jesus Garcia Lopez De'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/4'}, 'nombre': {'type': 'literal', 'value': 'Victor Rodriguez Fernandez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/13'}, 'nombre': {'type': 'literal', 'value': 'Celena Lorenzo Navarro'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/74'}, 'nombre': {'type': 'literal', 'value': 'Angel Arroyo Castillo'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/29'}, 'nombre': {'type': 'literal', 'value': 'Jose Ernesto Jimenez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/18'}, 'nombre': {'type': 'literal', 'value': 'Marta Olea De Cardenas'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/15'}, 'nombre': {'type': 'literal', 'value': 'Manuel Uche Soria'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/17'}, 'nombre': {'type': 'literal', 'value': 'M. Paula Fernandez Arias'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/71'}, 'nombre': {'type': 'literal', 'value': 'Raul Lara Cabrera'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/79'}, 'nombre': {'type': 'literal', 'value': 'Sergio Gil Borras'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/24'}, 'nombre': {'type': 'literal', 'value': 'Victor Jose Martinez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '6'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/38'}, 'nombre': {'type': 'literal', 'value': 'Jose Merodio Gomez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/20'}, 'nombre': {'type': 'literal', 'value': 'Andrea Jesus Cimmino'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/59'}, 'nombre': {'type': 'literal', 'value': 'Miguel Angel Diaz Martinez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/25'}, 'nombre': {'type': 'literal', 'value': 'Jesus Mayor Marquez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/97'}, 'nombre': {'type': 'literal', 'value': 'Roberto Muñoz Izquierdo'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/2'}, 'nombre': {'type': 'literal', 'value': 'Jose Ramon Sanchez Couso'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/36'}, 'nombre': {'type': 'literal', 'value': 'Aranzazu Corral Herrero'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/64'}, 'nombre': {'type': 'literal', 'value': 'Juan Alberto De Frutos'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/45'}, 'nombre': {'type': 'literal', 'value': 'Borja Bordel Sanchez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/16'}, 'nombre': {'type': 'literal', 'value': 'Jaime Juan Gonzalez Masip'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/37'}, 'nombre': {'type': 'literal', 'value': 'Juan Jose Martin Sotoca'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/62'}, 'nombre': {'type': 'literal', 'value': 'M. Elvira Martinez De Icaya'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/87'}, 'nombre': {'type': 'literal', 'value': 'Ana Isabel Lias Quintero'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/91'}, 'nombre': {'type': 'literal', 'value': 'Aurea Maria Anguera De'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/67'}, 'nombre': {'type': 'literal', 'value': 'Santiago Alonso Villaverde'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/70'}, 'nombre': {'type': 'literal', 'value': 'Maria Gema Bello Orgaz'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/68'}, 'nombre': {'type': 'literal', 'value': 'Edgar Talavera Muñoz'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/69'}, 'nombre': {'type': 'literal', 'value': 'Fernando Ortega Requena'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/110'}, 'nombre': {'type': 'literal', 'value': 'Jorge Enrique Perez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/80'}, 'nombre': {'type': 'literal', 'value': 'Joaquin Entrialgo Castaño'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/43'}, 'nombre': {'type': 'literal', 'value': 'Francisco Diaz Perez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/103'}, 'nombre': {'type': 'literal', 'value': 'Gonzalo Martinez Ruiz De'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/76'}, 'nombre': {'type': 'literal', 'value': 'Daniel Lopez Fernandez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/57'}, 'nombre': {'type': 'literal', 'value': 'Aldo Gordillo Mendez'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}
# {'profesor': {'type': 'uri', 'value': 'http://upm.es/ontology/Profesor/52'}, 'nombre': {'type': 'literal', 'value': 'Maria Soledad Delgado Sanz'}, 'numAsignaturas': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '5'}}

# %% [markdown]
# # Consulta 4
# Recursos bibliográficos por asignatura

# %%
query = """
PREFIX upm: <http://upm.es/ontology/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT ?asignatura ?asigNombre ?recurso ?titulo ?autor ?url WHERE {
  # ?asignatura rdf:type upm:Asignatura .
  OPTIONAL { ?asignatura upm:nombre ?asigNombre. }
  OPTIONAL {
    # ?asignatura upm:tieneRecursoBibliografico ?recurso .
    OPTIONAL { ?recurso upm:titulo ?titulo. }
    OPTIONAL { ?recurso upm:autor ?autor. }
    OPTIONAL { ?recurso upm:direccionURL ?url. }
  }
}
ORDER BY ?asigNombre

"""

response = requests.post(
    GRAPHDB_ENDPOINT,
    data={'query': query},
    headers={'Accept': 'application/sparql-results+json'}
)

if response.status_code == 200:
    results = response.json()
    for r in results['results']['bindings']:
        print(r)
else:
    print("Error:", response.status_code, response.text)
# Out:
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000733'}, 'asigNombre': {'type': 'literal', 'value': 'Administracion de Sistemas Operativos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000726'}, 'asigNombre': {'type': 'literal', 'value': 'Administracion y Gestion de Bases de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000734'}, 'asigNombre': {'type': 'literal', 'value': 'Administracion y Gestion de Redes'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001019'}, 'asigNombre': {'type': 'literal', 'value': 'Adquisición y Procesamiento Numérico de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000207'}, 'asigNombre': {'type': 'literal', 'value': 'Algebra'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000217'}, 'asigNombre': {'type': 'literal', 'value': 'Algebra'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000700'}, 'asigNombre': {'type': 'literal', 'value': 'Algebra'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000229'}, 'asigNombre': {'type': 'literal', 'value': 'Algebra'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000712'}, 'asigNombre': {'type': 'literal', 'value': 'Algoritmica y Complejidad'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000308'}, 'asigNombre': {'type': 'literal', 'value': 'Algoritmica y Complejidad'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000245'}, 'asigNombre': {'type': 'literal', 'value': 'Algoritmica y Complejidad'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000348'}, 'asigNombre': {'type': 'literal', 'value': 'Algoritmica y Complejidad'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001008'}, 'asigNombre': {'type': 'literal', 'value': 'Algoritmos y Estructuras de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001011'}, 'asigNombre': {'type': 'literal', 'value': 'Algorítmica Numérica'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000701'}, 'asigNombre': {'type': 'literal', 'value': 'Analisis Matematico'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000225'}, 'asigNombre': {'type': 'literal', 'value': 'Analisis Matematico'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000201'}, 'asigNombre': {'type': 'literal', 'value': 'Analisis Matematico'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000213'}, 'asigNombre': {'type': 'literal', 'value': 'Analisis Matematico'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000357'}, 'asigNombre': {'type': 'literal', 'value': 'Analisis y Desarrollo Estrategico de Empresas'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001027'}, 'asigNombre': {'type': 'literal', 'value': 'Aprendizaje Automático I'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001033'}, 'asigNombre': {'type': 'literal', 'value': 'Aprendizaje Automático II'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000304'}, 'asigNombre': {'type': 'literal', 'value': 'Arquitectura de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000713'}, 'asigNombre': {'type': 'literal', 'value': 'Arquitectura de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000241'}, 'asigNombre': {'type': 'literal', 'value': 'Arquitectura de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000346'}, 'asigNombre': {'type': 'literal', 'value': 'Arquitectura de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000253'}, 'asigNombre': {'type': 'literal', 'value': 'Arquitectura y Diseño Software'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000317'}, 'asigNombre': {'type': 'literal', 'value': 'Arquitecturas Avanzadas'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001024'}, 'asigNombre': {'type': 'literal', 'value': 'Arquitecturas para el Procesamiento Masivo de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000208'}, 'asigNombre': {'type': 'literal', 'value': 'Aspectos Eticos y Sociales'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000223'}, 'asigNombre': {'type': 'literal', 'value': 'Aspectos Eticos y Sociales'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000235'}, 'asigNombre': {'type': 'literal', 'value': 'Aspectos Eticos y Sociales'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000708'}, 'asigNombre': {'type': 'literal', 'value': 'Aspectos Eticos y Sociales'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000310'}, 'asigNombre': {'type': 'literal', 'value': 'Aspectos Legales y Profesionales'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000356'}, 'asigNombre': {'type': 'literal', 'value': 'Aspectos Legales y Profesionales'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000722'}, 'asigNombre': {'type': 'literal', 'value': 'Aspectos Legales y Profesionales'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000247'}, 'asigNombre': {'type': 'literal', 'value': 'Aspectos Legales y Profesionales'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001022'}, 'asigNombre': {'type': 'literal', 'value': 'Aspectos Sociales, éticos y Legales de los Datos y la\nInteligencia Artificial'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000369'}, 'asigNombre': {'type': 'literal', 'value': 'Auditoria y Control Ti'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000350'}, 'asigNombre': {'type': 'literal', 'value': 'Bases de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000300'}, 'asigNombre': {'type': 'literal', 'value': 'Bases de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000237'}, 'asigNombre': {'type': 'literal', 'value': 'Bases de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000714'}, 'asigNombre': {'type': 'literal', 'value': 'Bases de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000364'}, 'asigNombre': {'type': 'literal', 'value': 'Bases de Datos Avanzadas'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000256'}, 'asigNombre': {'type': 'literal', 'value': 'Bases de Datos Avanzados'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001020'}, 'asigNombre': {'type': 'literal', 'value': 'Bases de Datos I'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001030'}, 'asigNombre': {'type': 'literal', 'value': 'Bases de Datos II'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001055'}, 'asigNombre': {'type': 'literal', 'value': 'Bioinspired Algorithms For Optimization'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000259'}, 'asigNombre': {'type': 'literal', 'value': 'Calidad del Software'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001051'}, 'asigNombre': {'type': 'literal', 'value': 'Codificación de la Información'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000732'}, 'asigNombre': {'type': 'literal', 'value': 'Comercio Electronico'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000729'}, 'asigNombre': {'type': 'literal', 'value': 'Computacion Ubícua Movil y en la Nube'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001052'}, 'asigNombre': {'type': 'literal', 'value': 'Computación Cuántica'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001023'}, 'asigNombre': {'type': 'literal', 'value': 'Computación Social y Personalización'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000254'}, 'asigNombre': {'type': 'literal', 'value': 'Construccion y Diseño de Interfaces Graficas de Usuario'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001002'}, 'asigNombre': {'type': 'literal', 'value': 'Cálculo I'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001007'}, 'asigNombre': {'type': 'literal', 'value': 'Cálculo II'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000359'}, 'asigNombre': {'type': 'literal', 'value': 'Desarrollo de Sistemas de Informacion Orientados a\nServicios'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001053'}, 'asigNombre': {'type': 'literal', 'value': 'Desarrollo de Videojuegos e Inteligencia Artificia'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001038'}, 'asigNombre': {'type': 'literal', 'value': 'Descubrimiento de Conocimiento en Datos Complejos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000230'}, 'asigNombre': {'type': 'literal', 'value': 'Estructura de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000705'}, 'asigNombre': {'type': 'literal', 'value': 'Estructura de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000218'}, 'asigNombre': {'type': 'literal', 'value': 'Estructura de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000209'}, 'asigNombre': {'type': 'literal', 'value': 'Estructura de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000231'}, 'asigNombre': {'type': 'literal', 'value': 'Estructura de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000219'}, 'asigNombre': {'type': 'literal', 'value': 'Estructura de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000210'}, 'asigNombre': {'type': 'literal', 'value': 'Estructura de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000706'}, 'asigNombre': {'type': 'literal', 'value': 'Estructuras de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000255'}, 'asigNombre': {'type': 'literal', 'value': 'Evolucion y Mantenimiento del Software'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000702'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos Fisicos de la Informatica'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000232'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos Fisicos de la Informatica'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000220'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos Fisicos de la Informatica'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000212'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos Fisicos de la Informatica'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001028'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Análisis de Imágenes'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000226'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000202'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000704'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000214'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000238'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Economia y Empresa'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000351'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Economia y Empresa'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000301'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Economia y Empresa'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000718'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Economia y Empresas'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001017'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Economía y Administración de Empresas'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000353'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Ingenieria de Software'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000717'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Ingenieria del Software'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000303'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Ingenieria del Software'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000240'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Ingenieria del Software'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000215'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Programacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000707'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Programacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000227'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Programacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000203'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Programacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000710'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Seguridad'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000224'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Seguridad'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000236'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Seguridad'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000211'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Seguridad'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000358'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de Sistemas de Informacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001005'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de la Programación'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001009'}, 'asigNombre': {'type': 'literal', 'value': 'Fundamentos de los Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000370'}, 'asigNombre': {'type': 'literal', 'value': 'Gestion de Proyectos de Sistemas de Informacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000258'}, 'asigNombre': {'type': 'literal', 'value': 'Gestion de Proyectos y del Riesgo'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001031'}, 'asigNombre': {'type': 'literal', 'value': 'Infraestructuras de Big Data'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001025'}, 'asigNombre': {'type': 'literal', 'value': 'Infraestructuras y Servicios Cloud'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000252'}, 'asigNombre': {'type': 'literal', 'value': 'Ingenieria de Requisitos y Modelado'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000251'}, 'asigNombre': {'type': 'literal', 'value': 'Ingenieria del Proceso Software y Construccion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000309'}, 'asigNombre': {'type': 'literal', 'value': 'Inteligencia Artificial'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000246'}, 'asigNombre': {'type': 'literal', 'value': 'Inteligencia Artificial'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000349'}, 'asigNombre': {'type': 'literal', 'value': 'Inteligencia Artificial'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001013'}, 'asigNombre': {'type': 'literal', 'value': 'Inteligencia Artificial'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000715'}, 'asigNombre': {'type': 'literal', 'value': 'Inteligencia Artificial'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001036'}, 'asigNombre': {'type': 'literal', 'value': 'Internet de las Cosas (Iot)'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001026'}, 'asigNombre': {'type': 'literal', 'value': 'Investigación Operativa'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000204'}, 'asigNombre': {'type': 'literal', 'value': 'Logica y Matematica Discreta'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000216'}, 'asigNombre': {'type': 'literal', 'value': 'Logica y Matematica Discreta'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000228'}, 'asigNombre': {'type': 'literal', 'value': 'Logica y Matematica Discreta'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000703'}, 'asigNombre': {'type': 'literal', 'value': 'Logica y Matematica Discreta'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001004'}, 'asigNombre': {'type': 'literal', 'value': 'Lógica para Inteligencia Artificial'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001003'}, 'asigNombre': {'type': 'literal', 'value': 'Matemática Discreta I'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001010'}, 'asigNombre': {'type': 'literal', 'value': 'Matemática Discreta II'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000363'}, 'asigNombre': {'type': 'literal', 'value': 'Mejores Practicas para Gestion de Servicios'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000368'}, 'asigNombre': {'type': 'literal', 'value': 'Metricas y Modelos para el Control y Gestion de Servicios'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000365'}, 'asigNombre': {'type': 'literal', 'value': 'Mineria de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001061'}, 'asigNombre': {'type': 'literal', 'value': 'Mobile App Development'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001029'}, 'asigNombre': {'type': 'literal', 'value': 'Métodos Clásicos para Predicción'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001054'}, 'asigNombre': {'type': 'literal', 'value': 'Métodos Generativos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000362'}, 'asigNombre': {'type': 'literal', 'value': 'Planificacion y Organización del Capital Humano'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000302'}, 'asigNombre': {'type': 'literal', 'value': 'Probabilidad y Estadistica'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000239'}, 'asigNombre': {'type': 'literal', 'value': 'Probabilidad y Estadistica'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000719'}, 'asigNombre': {'type': 'literal', 'value': 'Probabilidad y Estadistica'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000352'}, 'asigNombre': {'type': 'literal', 'value': 'Probabilidad y Estadística'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001006'}, 'asigNombre': {'type': 'literal', 'value': 'Probabilidades y Estadística I'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001018'}, 'asigNombre': {'type': 'literal', 'value': 'Probabilidades y Estadística II'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001057'}, 'asigNombre': {'type': 'literal', 'value': 'Procesamiento Digital de la Señal'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000725'}, 'asigNombre': {'type': 'literal', 'value': 'Procesamiento Paralelo'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001014'}, 'asigNombre': {'type': 'literal', 'value': 'Procesamiento de Lenguaje Natural'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000305'}, 'asigNombre': {'type': 'literal', 'value': 'Programacion Concurrente y Avanzada'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000242'}, 'asigNombre': {'type': 'literal', 'value': 'Programacion Concurrente y Avanzada'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000354'}, 'asigNombre': {'type': 'literal', 'value': 'Programacion Concurrente y Avanzada'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000720'}, 'asigNombre': {'type': 'literal', 'value': 'Programacion Concurrente y Avanzada'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000716'}, 'asigNombre': {'type': 'literal', 'value': 'Programacion Orientada a Objetos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000243'}, 'asigNombre': {'type': 'literal', 'value': 'Programacion Orientada a Objetos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000306'}, 'asigNombre': {'type': 'literal', 'value': 'Programacion Orientada a Objetos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000347'}, 'asigNombre': {'type': 'literal', 'value': 'Programacion Orientada a Objetos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000319'}, 'asigNombre': {'type': 'literal', 'value': 'Programacion de Hw Reconfigurable'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001016'}, 'asigNombre': {'type': 'literal', 'value': 'Programación para Ciencia de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001039'}, 'asigNombre': {'type': 'literal', 'value': 'Proyecto de Ciencia de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000728'}, 'asigNombre': {'type': 'literal', 'value': 'Redes Avanzadas'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000360'}, 'asigNombre': {'type': 'literal', 'value': 'Redes de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000249'}, 'asigNombre': {'type': 'literal', 'value': 'Redes de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000312'}, 'asigNombre': {'type': 'literal', 'value': 'Redes de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000723'}, 'asigNombre': {'type': 'literal', 'value': 'Redes de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001012'}, 'asigNombre': {'type': 'literal', 'value': 'Representación e Intercambio de Datos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000334'}, 'asigNombre': {'type': 'literal', 'value': 'Robotica'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001034'}, 'asigNombre': {'type': 'literal', 'value': 'Robótica'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000244'}, 'asigNombre': {'type': 'literal', 'value': 'Seguridad de la Informacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000355'}, 'asigNombre': {'type': 'literal', 'value': 'Seguridad de la Informacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000307'}, 'asigNombre': {'type': 'literal', 'value': 'Seguridad de la Informacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000721'}, 'asigNombre': {'type': 'literal', 'value': 'Seguridad de la Informacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001021'}, 'asigNombre': {'type': 'literal', 'value': 'Seguridad de las Tecnologías de la Información'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000730'}, 'asigNombre': {'type': 'literal', 'value': 'Seguridad en Sistemas y Redes'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000316'}, 'asigNombre': {'type': 'literal', 'value': 'Seguridad en Sistemas y Redes'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000335'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas Basados en Computador'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000735'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas Distribuidos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000491'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas Empotrados'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000470'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas Inteligentes'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000313'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas Operativos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000250'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas Operativos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000724'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas Operativos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000361'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas Operativos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001064'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas de Control'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000366'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas de Informacion Geografica'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000371'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas de Soporte a la Toma de Decisiones'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000492'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas de Tiempo Real'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001059'}, 'asigNombre': {'type': 'literal', 'value': 'Sistemas y Servicios de Navegación Gps'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000222'}, 'asigNombre': {'type': 'literal', 'value': 'Taller de Programacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000709'}, 'asigNombre': {'type': 'literal', 'value': 'Taller de Programacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000234'}, 'asigNombre': {'type': 'literal', 'value': 'Taller de Programacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000206'}, 'asigNombre': {'type': 'literal', 'value': 'Taller de Programacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000221'}, 'asigNombre': {'type': 'literal', 'value': 'Taller de Sistemas Operativos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000233'}, 'asigNombre': {'type': 'literal', 'value': 'Taller de Sistemas Operativos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000205'}, 'asigNombre': {'type': 'literal', 'value': 'Taller de Sistemas Operativos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000711'}, 'asigNombre': {'type': 'literal', 'value': 'Taller de Sistemas Operativos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000318'}, 'asigNombre': {'type': 'literal', 'value': 'Tecnologia de Computadores'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001065'}, 'asigNombre': {'type': 'literal', 'value': 'Tecnologías de Dearrollo para la Web'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000248'}, 'asigNombre': {'type': 'literal', 'value': 'Traductores de Lenguajes de Programacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000390'}, 'asigNombre': {'type': 'literal', 'value': 'Traductores de Lenguajes de Programacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000311'}, 'asigNombre': {'type': 'literal', 'value': 'Traductores de Lenguajes de Programacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000727'}, 'asigNombre': {'type': 'literal', 'value': 'Traductores de Lenguajes de Programacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615000260'}, 'asigNombre': {'type': 'literal', 'value': 'Verificacion y Validacion'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001032'}, 'asigNombre': {'type': 'literal', 'value': 'Visualización de Información'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001063'}, 'asigNombre': {'type': 'literal', 'value': 'Web Development'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001015'}, 'asigNombre': {'type': 'literal', 'value': 'Web Semántica, Linked Data y Grafos de Conocimientos'}}
# {'asignatura': {'type': 'uri', 'value': 'http://upm.es/ontology/Asignatura/615001001'}, 'asigNombre': {'type': 'literal', 'value': 'álgebra Lineal'}}

# %% [markdown]
# # Consulta 5
# Distribución del número de creditos por asignatura (indicadores: media, mínimo, máximo)

# %%
query = """
PREFIX upm: <http://upm.es/ontology/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT ?titulacion ?titNombre (AVG(?c) AS ?avgCreditos) (MIN(?c) AS ?minCreditos) (MAX(?c) AS ?maxCreditos) WHERE {
  # ?titulacion a upm:Titulacion .
  OPTIONAL { ?titulacion upm:nombre ?titNombre. }
  # ?titulacion upm:incluyeAsignatura ?asig .
  # ?asig upm:creditosECTS ?c .
}
GROUP BY ?titulacion ?titNombre
ORDER BY DESC(?avgCreditos)
"""

response = requests.post(
    GRAPHDB_ENDPOINT,
    data={'query': query},
    headers={'Accept': 'application/sparql-results+json'}
)

if response.status_code == 200:
    results = response.json()
    for r in results['results']['bindings']:
        print(r)
else:
    print("Error:", response.status_code, response.text)
# Out:
# {'titulacion': {'type': 'uri', 'value': 'http://upm.es/ontology/Titulacion/61CD'}, 'titNombre': {'type': 'literal', 'value': 'Grado en Ciencia de Datos e Inteligencia Artificial'}, 'minCreditos': {'type': 'literal', 'value': '3'}, 'maxCreditos': {'type': 'literal', 'value': '6'}}
# {'titulacion': {'type': 'uri', 'value': 'http://upm.es/ontology/Titulacion/61SI'}, 'titNombre': {'type': 'literal', 'value': 'Grado en Sistemas de Informacion'}, 'minCreditos': {'type': 'literal', 'value': '3'}, 'maxCreditos': {'type': 'literal', 'value': '9'}}
# {'titulacion': {'type': 'uri', 'value': 'http://upm.es/ontology/Titulacion/61CI'}, 'titNombre': {'type': 'literal', 'value': 'Grado en Ingenieria de Computadores'}, 'minCreditos': {'type': 'literal', 'value': '3'}, 'maxCreditos': {'type': 'literal', 'value': '9'}}
# {'titulacion': {'type': 'uri', 'value': 'http://upm.es/ontology/Titulacion/61TI'}, 'titNombre': {'type': 'literal', 'value': 'Grado en Tecnologias para la Sociedad de la Informacion'}, 'minCreditos': {'type': 'literal', 'value': '3'}, 'maxCreditos': {'type': 'literal', 'value': '9'}}
# {'titulacion': {'type': 'uri', 'value': 'http://upm.es/ontology/Titulacion/61IW'}, 'titNombre': {'type': 'literal', 'value': 'Grado en Ingenieria del Software'}, 'minCreditos': {'type': 'literal', 'value': '3'}, 'maxCreditos': {'type': 'literal', 'value': '9'}}
